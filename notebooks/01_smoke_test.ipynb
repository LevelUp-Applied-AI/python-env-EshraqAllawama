# %%
import pandas as pd
import sys

# %%
df = pd.read_csv("../data/sample.csv")

# %%
# full data’s information 
print("Shape: ", df.shape)
print("head: ", df.head())
print("describe: ", df.describe())
# Out:
# Shape:  (5, 3)
# head:      name  score  passed
# 0  Alice     85    True
# 1    Bob     72    True
# 2  Carol     60   False
# 3  Diana     91    True
# 4    Eve     45   False
# describe:             score
# count   5.000000
# mean   70.600000
# std    18.662797
# min    45.000000
# 25%    60.000000
# 50%    72.000000
# 75%    85.000000
# max    91.000000
